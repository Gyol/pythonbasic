# %% [markdown]
# ####  특정 웹툰 페이지 모든 image를 다운로드하기
# * soup.select('img[src$=jpg]')
# * img 폴더를 생성해서 그 아래에 파일들 저장

# %%
import requests
from bs4 import BeautifulSoup
import os

mainurl = 'https://comic.naver.com/webtoon/detail.nhn?titleId=626906&no=602&amp;weekday=tue'
res = requests.get(mainurl)
getdata = res.text # text로 개발자도구에 있는 element 전부 받아오는 명령어
soup = BeautifulSoup(getdata, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <title>패밀리 사이즈 :: 네이버 만화</title>
# <meta content="패밀리 사이즈 - 시즌2 496화" property="og:title"/>
# <meta content="https://shared-comic.pstatic.net/thumb/webtoon/626906/602/thumbnail_600x315_4b214874-6977-49c8-bf6d-ee85be2c8aee.jpg" property="og:image"/>
# <meta content="시즌2 496화" property="og:description"/>
# <meta content="https://comic.naver.com/webtoon/detail.nhn?titleId=626906&amp;no=602&amp;amp;weekday=tue" property="og:url"/>
# <meta content="article" property="og:type"/>
# <meta content="네이버 웹툰" property="og:article:author"/>
# <meta content="https://comic.naver.com" property="og:article:author:url"/>
# <link href="https://ssl.pstatic.net/static/comic/favicon/webtoon_favicon_32x32.ico" rel="shortcut icon" type="image/x-icon"/>
# <script type="text/javascript">
# 		document.domain = "naver.com";
# 	</script>
# ...

# %%
import requests
from bs4 import BeautifulSoup
import os

mainurl = 'https://comic.naver.com/webtoon/detail.nhn?titleId=626906&no=602&amp;weekday=tue'
res = requests.get(mainurl)
getdata = res.text # text로 개발자도구에 있는 element 전부 받아오는 명령어
soup = BeautifulSoup(getdata, 'html.parser')

imgur = [] # image url을 받아올 list 생성

for imguvari in soup.select("img[src$='.jpg']"): # .jpg로 끝나는애들을 긁어오겠다는 뜻
    # print(imguvari) # 이거해보니까 웹툰 본문 말고 기타 썸네일이나 광고 등등도 긁혀오넹
    imgur.append(imguvari['src'])
# print(len(imgur), imgur)

# 디렉토리 생성
if not os.path.isdir('family size'):
    os.mkdir('family size')

print(len(imgur))
for imguvari in imgur:
    print(imgur)
    req_header = {
        'referer': mainurl
    }
    
    res2 = requests.get(imgur. headers = req_header)
# Out:
# 24
# ...
